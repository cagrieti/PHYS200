# %%
# !pip uninstall -y torch torchaudio torchvision
# !pip install torch==2.4.1 torchvision==0.19.1 torchaudio==2.4.1 --index-url https://download.pytorch.org/whl/cu121
# !pip install --upgrade transformers==4.44.2 gradio==4.44.0 accelerate safetensors huggingface_hub pydub soundfile
# Out:
# Found existing installation: torch 2.3.1+cu121
# Uninstalling torch-2.3.1+cu121:
#   Successfully uninstalled torch-2.3.1+cu121
# Found existing installation: torchaudio 2.3.1+cu121
# Uninstalling torchaudio-2.3.1+cu121:
#   Successfully uninstalled torchaudio-2.3.1+cu121
# Found existing installation: torchvision 0.18.1+cu121
# Uninstalling torchvision-0.18.1+cu121:
#   Successfully uninstalled torchvision-0.18.1+cu121
# Looking in indexes: https://download.pytorch.org/whl/cu121
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 798.9/798.9 MB 1.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.1/7.1 MB 94.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 52.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 209.5/209.5 MB 5.1 MB/s eta 0:00:00
# ...
#   Attempting uninstall: triton
#     Found existing installation: triton 3.5.0
# ...

# %%
import torch
print(torch.__version__)  # Should print 2.4.1+cu121 or similar
print(hasattr(torch.nn, 'RMSNorm'))  # Should print True
# Out:
# 2.4.1+cu121
# True

# %%
# !git clone https://github.com/fishaudio/fish-speech.git
# %cd fish-speech
# !pip install -e .   # If not already done — installs the package
# Out:
# fatal: destination path 'fish-speech' already exists and is not an empty directory.
# /content/fish-speech
# Obtaining file:///content/fish-speech
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# ...
#   Using cached numpy-1.26.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
# ...
#   Using cached transformers-5.1.0-py3-none-any.whl.metadata (31 kB)
# ...
#   Using cached datasets-2.18.0-py3-none-any.whl.metadata (20 kB)
# ...
#   Using cached lightning-2.6.1-py3-none-any.whl.metadata (44 kB)
# ...
#   Using cached gradio-6.5.1-py3-none-any.whl.metadata (16 kB)
# ...
#   Using cached resampy-0.4.3-py3-none-any.whl.metadata (3.0 kB)
# ...
#   Using cached einx-0.2.2-py3-none-any.whl.metadata (6.8 kB)
# ...
#   Using cached PyAudio-0.2.14.tar.gz (47 kB)
#   Installing build dependencies ... done
# ...

# %%
# %cd /content/fish-speech
# !pwd  # should now show /content/fish-speech
# !ls tools/  # should list run_webui.py and others
# Out:
# /content/fish-speech
# /content/fish-speech
# api_client.py  download_models.py  run_webui.py  vqgan
# api_server.py  llama		   server	 webui

# %% [markdown]
# # Fish Speech

# %%
from huggingface_hub import login
login()  # When prompted, paste your hf_ token and press Enter

# %% [markdown]
# ### Prepare Model

# %%
# For Chinese users, you probably want to use mirror to accelerate downloading
# !set HF_ENDPOINT=https://hf-mirror.com
# !export HF_ENDPOINT=https://hf-mirror.com

# !hf download fishaudio/openaudio-s1-mini --local-dir checkpoints/openaudio-s1-mini/
# Out:
# Fetching 7 files: 100% 7/7 [00:00<00:00, 78925.08it/s]
# /content/checkpoints/openaudio-s1-mini

# %%
# !pwd   # Should show something like /content or /content/fish-speech
# !ls tools/   # This lists files in tools/ — look for run_webui.py (not run_webuui.py or similar)
# Out:
# /content/fish-speech
# api_client.py  download_models.py  run_webui.py  vqgan
# api_server.py  llama		   server	 webui

# %% [markdown]
# ## WebUI Inference
#
# > You can use --compile to fuse CUDA kernels for faster inference (10x).

# %%
# !pip install pyrootutils
# !pip install hydra-core loguru rich einops natsort pyrootutils kui loralib

# %%
# !pip install descript-audiotools descript-audio-codec hydra-core loguru rich einops natsort pyrootutils

# %%
# !pip install lightning

# %%
# !python tools/run_webui.py \  #alternative DO NOT USE IT
    --llama-checkpoint-path checkpoints/openaudio-s1-mini \
    --decoder-checkpoint-path checkpoints/openaudio-s1-mini/codec.pth \
    # --compile
# Out:
# 2026-02-14 23:00:56.499456: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1771110056.519962   10739 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1771110056.526088   10739 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1771110056.542277   10739 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...

# %%
# !GRADIO_SHARE=1 python tools/run_webui.py \
  --llama-checkpoint-path checkpoints/openaudio-s1-mini \
  --decoder-checkpoint-path checkpoints/openaudio-s1-mini/codec.pth
# Out:
# 2026-02-14 23:08:04.269966: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1771110484.342481   12777 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1771110484.357749   12777 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1771110484.393373   12777 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...

# %% [markdown]
# ## Break-down CLI Inference

# %% [markdown]
# ### 1. Encode reference audio: / 从语音生成 prompt:
#
# You should get a `fake.npy` file.
#
# 你应该能得到一个 `fake.npy` 文件.

# %%
## Enter the path to the audio file here
src_audio = r"D:\PythonProject\vo_hutao_draw_appear.wav"

# !python fish_speech/models/dac/inference.py \
    -i {src_audio} \
    --checkpoint-path "checkpoints/openaudio-s1-mini/codec.pth"

from IPython.display import Audio, display
audio = Audio(filename="fake.wav")
display(audio)

# %% [markdown]
# ### 2. Generate semantic tokens from text: / 从文本生成语义 token:
#
# > This command will create a codes_N file in the working directory, where N is an integer starting from 0.
#
# > You may want to use `--compile` to fuse CUDA kernels for faster inference (~30 tokens/second -> ~300 tokens/second).
#
# > 该命令会在工作目录下创建 codes_N 文件, 其中 N 是从 0 开始的整数.
#
# > 您可以使用 `--compile` 来融合 cuda 内核以实现更快的推理 (~30 tokens/秒 -> ~300 tokens/秒)

# %%
# !python fish_speech/models/text2semantic/inference.py \
    --text "hello world" \
    --prompt-text "The text corresponding to reference audio" \
    --prompt-tokens "fake.npy" \
    --checkpoint-path "checkpoints/openaudio-s1-mini" \
    --num-samples 2
    # --compile

# %% [markdown]
# ### 3. Generate speech from semantic tokens: / 从语义 token 生成人声:

# %%
# !python fish_speech/models/dac/inference.py \
    -i "codes_0.npy" \
    --checkpoint-path "checkpoints/openaudio-s1-mini/codec.pth"

from IPython.display import Audio, display
audio = Audio(filename="fake.wav")
display(audio)
